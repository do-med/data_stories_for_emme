# %% [markdown]
# <a href="https://colab.research.google.com/github/do-med/data_stories_for_emme/blob/main/exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Άσκηση 1
#
# Φτιάξτε ένα σύνολο δεδομένων με πληροφορίες για 3 άρθρα από ένα δημοσιογραφικό site της επιλογής σας.
#
# Οι πληροφορίες για κάθε άρθρο, θα είναι:
# - τίτλος του άρθρου
# - url του άρθρου
# - συντάκτης του άρθρου
# - θεματική κατηγορία άρθρου
# - ημερομηνία δημοσίευσης του άρθρου
#
# Οι πληροφορίες για κάθε άρθρο θα τοποθετηθούν σε ένα λεξικό.
#
# Το σύνολο των δεδομένων της αρθρογραφίας των 3 άρθρων θα είναι μια λίστα, η οποία θα περιέχει τα 3 λεξικά.
#
# **Παράδειγμα λεξικού (dictionary) με πληροφορίες για ένα άρθρο**:
# ```
# articleD_1 = {
#   "title": "Συναγερμός για κρούσμα κροτωνογενούς εγκεφαλίτιδας στην Ελλάδα – Εγκύκλιος ΕΟΔΥ",
#   "url": "https://www.news247.gr/ygeia/sinagermos-gia-krousma-krotonogenous-egkefalitidas-stin-ellada-egkiklios-eodi/",
#   "author": "ΓΙΑΝΝΗΣ ΔΕΒΕΤΖΟΓΛΟΥ",
#   "section": "Υγεία",
#   "date": "27 Μαρτίου 2025 13:40"
# }
# ```
#
# **Hints & Tips:**
# - αρχικά μπορείτε να δημιουργήσετε μια κενή λίστα με όνομα π.χ. "articlesL"
# - στη συνέχεια μπορείτε να δημιουργείτε ένα-ένα τα λεξικά με τις πληροφορίες για τα άρθρα (όπως στο παραπάνω παράδειγμα) και
# - να προσθέτε ένα-ένα τα λεξικά στη λίστα με append()
# - τέλος, καλέστε τη λίστα των άρθρων με το όνομά της για να εμφανιστεί στην οθόνη (μπορείτε να την κάνετε και print για να δείτε τη διαφορά στον τρόπο που εμφανίζεται η λίστα στην οθόνη)

# %%
articlesL=[]

articleD1={
    "title":"The big idea: should we abolish art?",
    "url":"https://www.theguardian.com/books/2025/mar/10/the-big-idea-should-we-abolish-art",
    "author":"Morgan Falconer",
    "section":"art",
    "date":"Mon 10 Mar 2025 13.30 CET"
}
articlesL.append(articleD1)

articleD2={
    "title":"TV tonight: how ‘skinny jabs’ became a cultural obsession",
    "url":"https://www.theguardian.com/tv-and-radio/2025/mar/10/tv-tonight-how-skinny-jabs-became-a-cultural-obsession",
    "author":"Hollie Richardson, Jack Seale, Phil Harrison and Simon Wardell",
    "section":"tv and radio",
    "date":"Tue 4 Mar 2025 07.20 CET"
}
articlesL.append(articleD2)
articleD3={
    "title":"Ireland's time-warped island of Owey is the perfect place to disconnect",
    "url":"https://www.theguardian.com/world/2025/mar/10/irelands-time-warped-island-of-owey-is-the-perfect-place-to-disconnect",
    "author":"Julie Diamond",
    "section":"world",
    "date":"3 March 2025"
}
articlesL.append(articleD3)
print(articlesL)
# Out:
# [{'title': 'The big idea: should we abolish art?', 'url': 'https://www.theguardian.com/books/2025/mar/10/the-big-idea-should-we-abolish-art', 'author': 'Morgan Falconer', 'section': 'art', 'date': 'Mon 10 Mar 2025 13.30 CET'}, {'title': 'TV tonight: how ‘skinny jabs’ became a cultural obsession', 'url': 'https://www.theguardian.com/tv-and-radio/2025/mar/10/tv-tonight-how-skinny-jabs-became-a-cultural-obsession', 'author': 'Hollie Richardson, Jack Seale, Phil Harrison and Simon Wardell', 'section': 'tv and radio', 'date': 'Tue 4 Mar 2025 07.20 CET'}, {'title': "Ireland's time-warped island of Owey is the perfect place to disconnect", 'url': 'https://www.theguardian.com/world/2025/mar/10/irelands-time-warped-island-of-owey-is-the-perfect-place-to-disconnect', 'author': 'Julie Diamond', 'section': 'world', 'date': '3 March 2025'}]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 2
#
# Μετατρέψτε τη λίστα με τα λεξικά που φτιάξατε στην προηγούμενη άσκηση σε pandas dataframe.
#
# **Hints & Tips:**
# - Εισάγετε τη βιβλιοθήκη pandas με την εντολή ```import pandas as pd```
# - Δημιουργήστε ένα dataframe με όνομα ```df```, με την εντολή ```df = pd.DataFrame(articlesL)```
# - Καλέστε το df για να εμφανιστεί στην οθόνη

# %%
import pandas as pd
df = pd.DataFrame(articlesL)
df
# Out:
#                                                title  \
# 0               The big idea: should we abolish art?
# 1  TV tonight: how ‘skinny jabs’ became a cultura...
# 2  Ireland's time-warped island of Owey is the pe...
#
#                                                  url  \
# 0  https://www.theguardian.com/books/2025/mar/10/...
# 1  https://www.theguardian.com/tv-and-radio/2025/...
# 2  https://www.theguardian.com/world/2025/mar/10/...
#
#                                               author       section  \
# 0                                    Morgan Falconer           art
# 1  Hollie Richardson, Jack Seale, Phil Harrison a...  tv and radio
# 2                                      Julie Diamond         world
#
#                         date
# 0  Mon 10 Mar 2025 13.30 CET
# 1   Tue 4 Mar 2025 07.20 CET
# 2               3 March 2025

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (intro)
#
# Στο site "ourworldindata.org" παρέχονται πάρα πολλά δεδομένα και γραφήματα για διάφορα topics για όλες τις χώρες του κόσμου.
#
# Για παράδειγμα, στη σελίδα https://ourworldindata.org/explorers/covid?Metric=Excess+mortality+%28estimates%29&Interval=Cumulative&Relative+to+population=false&country=USA~BRA~JPN~DEU, παρέχονται δεδομένα και γραφήματα σχετικά με την Covid-19.
#
# Αν επισκεφθείτε την παραπάνω σελίδα, επάνω αριστερά, υπάρχει ένας υπερσύνδεσμος με το κείμενο "Download this dataset". Εάν τον πατήσετε θα οδηγηθείτε στη σελίδα με τα datasets για τον covid.
#
# Πιο κάτω, σ' αυτή τη σελίδα, υπάρχει η ενότητα "Download data", με πολλά κουμπάκια download.
#
# Όταν πατήσετε κάποιο download μεταφέρεστε στη σελίδα του raw αρχείου csv με τα δεδομένα.
#
# Μπορούμε να φέρουμε αυτά τα δεδομένα σε ένα dataframe στην Python, με την παρακάτω εντολή:

# %%
import pandas as pd

covid_df = pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid_df
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 471245     Zimbabwe  2025-02-26        0.0       266410         0.0
# 471246     Zimbabwe  2025-02-27        0.0       266410         0.0
# 471247     Zimbabwe  2025-02-28        0.0       266410         0.0
# 471248     Zimbabwe  2025-03-01        0.0       266410         0.0
# 471249     Zimbabwe  2025-03-02        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 471245          5740           0.0            0.0                      NaN
# 471246          5740           0.0            0.0                      NaN
# 471247          5740           0.0            0.0                      NaN
# 471248          5740           0.0            0.0                      NaN
# 471249          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 471245                       NaN  ...       2.154574             NaN
# 471246                       NaN  ...       2.154574             NaN
# 471247                       NaN  ...       2.154574             NaN
# 471248                       NaN  ...       2.154574             NaN
# 471249                       NaN  ...       2.154574             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 471245                      1737.0                     1819.0
# 471246                      1738.0                     1820.0
# 471247                      1739.0                     1821.0
# 471248                      1740.0                     1822.0
# 471249                      1741.0                     1823.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 471245                                1779.0
# 471246                                1780.0
# 471247                                1781.0
# 471248                                1782.0
# 471249                                1783.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 471245                                   1819.0
# 471246                                   1820.0
# 471247                                   1821.0
# 471248                                   1822.0
# 471249                                   1823.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 471245                                 1737.0                   0.0
# 471246                                 1738.0                   0.0
# 471247                                 1739.0                   0.0
# 471248                                 1740.0                   0.0
# 471249                                 1741.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 471245                            0.0                               0.0
# 471246                            0.0                               0.0
# 471247                            0.0                               0.0
# 471248                            0.0                               0.0
# 471249                            0.0                               0.0
#
# [471250 rows x 40 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Άσκηση 3 (actual part)
#
# Βρείτε από το ourworldindata.org ένα dataset που σας ενδιαφέρει και ανοίξτε το σαν dataframe.

# %%
import pandas as pd
covid19D=pd.read_csv("https://catalog.ourworldindata.org/garden/covid/latest/cases_deaths/cases_deaths.csv")
covid19D
# Out:
#             country        date  new_cases  total_cases  new_deaths  \
# 0       Afghanistan  2020-01-04        0.0            0         0.0
# 1       Afghanistan  2020-01-05        0.0            0         0.0
# 2       Afghanistan  2020-01-06        0.0            0         0.0
# 3       Afghanistan  2020-01-07        0.0            0         0.0
# 4       Afghanistan  2020-01-08        0.0            0         0.0
# ...             ...         ...        ...          ...         ...
# 472846     Zimbabwe  2025-03-12        0.0       266410         0.0
# 472847     Zimbabwe  2025-03-13        0.0       266410         0.0
# 472848     Zimbabwe  2025-03-14        0.0       266410         0.0
# 472849     Zimbabwe  2025-03-15        0.0       266410         0.0
# 472850     Zimbabwe  2025-03-16        0.0       266410         0.0
#
#         total_deaths  weekly_cases  weekly_deaths  weekly_pct_growth_cases  \
# 0                  0           NaN            NaN                      NaN
# 1                  0           NaN            NaN                      NaN
# 2                  0           NaN            NaN                      NaN
# 3                  0           NaN            NaN                      NaN
# 4                  0           NaN            NaN                      NaN
# ...              ...           ...            ...                      ...
# 472846          5740           0.0            0.0                      NaN
# 472847          5740           0.0            0.0                      NaN
# 472848          5740           0.0            0.0                      NaN
# 472849          5740           0.0            0.0                      NaN
# 472850          5740           0.0            0.0                      NaN
#
#         weekly_pct_growth_deaths  ...  cfr_100_cases  cfr_short_term  \
# 0                            NaN  ...            NaN             NaN
# 1                            NaN  ...            NaN             NaN
# 2                            NaN  ...            NaN             NaN
# 3                            NaN  ...            NaN             NaN
# 4                            NaN  ...            NaN             NaN
# ...                          ...  ...            ...             ...
# 472846                       NaN  ...       2.154574             NaN
# 472847                       NaN  ...       2.154574             NaN
# 472848                       NaN  ...       2.154574             NaN
# 472849                       NaN  ...       2.154574             NaN
# 472850                       NaN  ...       2.154574             NaN
#
#         days_since_100_total_cases  days_since_5_total_deaths  \
# 0                            -86.0                      -91.0
# 1                            -85.0                      -90.0
# 2                            -84.0                      -89.0
# 3                            -83.0                      -88.0
# 4                            -82.0                      -87.0
# ...                            ...                        ...
# 472846                      1751.0                     1833.0
# 472847                      1752.0                     1834.0
# 472848                      1753.0                     1835.0
# 472849                      1754.0                     1836.0
# 472850                      1755.0                     1837.0
#
#         days_since_1_total_cases_per_million  \
# 0                                      -81.0
# 1                                      -80.0
# 2                                      -79.0
# 3                                      -78.0
# 4                                      -77.0
# ...                                      ...
# 472846                                1793.0
# 472847                                1794.0
# 472848                                1795.0
# 472849                                1796.0
# 472850                                1797.0
#
#         days_since_0_1_total_deaths_per_million  \
# 0                                         -91.0
# 1                                         -90.0
# 2                                         -89.0
# 3                                         -88.0
# 4                                         -87.0
# ...                                         ...
# 472846                                   1833.0
# 472847                                   1834.0
# 472848                                   1835.0
# 472849                                   1836.0
# 472850                                   1837.0
#
#         days_since_100_total_cases_and_5m_pop  total_deaths_last12m  \
# 0                                       -86.0                   NaN
# 1                                       -85.0                   NaN
# 2                                       -84.0                   NaN
# 3                                       -83.0                   NaN
# 4                                       -82.0                   NaN
# ...                                       ...                   ...
# 472846                                 1751.0                   0.0
# 472847                                 1752.0                   0.0
# 472848                                 1753.0                   0.0
# 472849                                 1754.0                   0.0
# 472850                                 1755.0                   0.0
#
#         total_deaths_per_100k_last12m  total_deaths_per_million_last12m
# 0                                 NaN                               NaN
# 1                                 NaN                               NaN
# 2                                 NaN                               NaN
# 3                                 NaN                               NaN
# 4                                 NaN                               NaN
# ...                               ...                               ...
# 472846                            0.0                               0.0
# 472847                            0.0                               0.0
# 472848                            0.0                               0.0
# 472849                            0.0                               0.0
# 472850                            0.0                               0.0
#
# [472851 rows x 40 columns]
