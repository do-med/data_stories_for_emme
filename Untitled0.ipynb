# %% [markdown]
# <a href="https://colab.research.google.com/github/do-med/data_stories_for_emme/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/seismoi_csv!.csv", sep=',', encoding='ISO-8859-7', on_bad_lines='skip')

# %%
df
# Out:
#      type             source  \
# 0     web      adieksodos.gr
# 1     web         antenna.gr
# 2     web         antenna.gr
# 3     web    nicemagazine.gr
# 4       X    fayssecretsssss
# ...   ...                ...
# 2785    X       PANGKAKISTOS
# 2786    X     ekklisiaonline
# 2787    X       g_prince_tak
# 2788  web   pentapostagma.gr
# 2789  web  halkidikivoice.gr
#
#                                                   title  \
# 0     Σεισμός 4,8 Ρίχτερ στον Κορινθιακό  Προβληματ...
# 1                                  Σεισμός στη Μεσσηνία
# 2     Κρήτη: Σφοδρή σύγκρουση τριών οχημάτων, ταυματ...
# 3     Σεισμός 4,8 Ρίχτερ στον Κορινθιακό  Προβληματ...
# 4     https://x.com/fayssecretsssss/status/192745726...
# ...                                                 ...
# 2785  https://x.com/PANGKAKISTOS/status/192638894749...
# 2786  https://x.com/ekklisiaonline/status/1926369528...
# 2787  https://x.com/g_prince_tak/status/192637505857...
# ...

# %%
df.columns
# Out:
# Index(['type,source,title,text,categories,sentiment,date,time,link'], dtype='object')

# %%
df["source"].unique()
# Out:
# array(['adieksodos.gr', 'antenna.gr', 'nicemagazine.gr', ...,
#        'Lucy75218876', 'g_prince_tak', 'halkidikivoice.gr'], dtype=object)

# %%
df.source.nunique()
# Out:
# 1132

# %%
sorted(list(df["source"].unique()))#[:10]
# Out:
# ['1069.gr',
#  '12nisospress.com',
#  '14PAO88',
#  '15minutes.gr',
#  '1978paok',
#  '1VanessaRoxx',
#  '1metal3',
#  '2Cowman57',
#  '30__kai',
#  '4frontlinenews',
#  '5555Aris',
#  '6ATK9',
#  '7Vercost',
#  '902.gr',
#  '94fm.gr',
#  '94tony19',
#  'ADikaiou',
#  'AKapsoulaki',
#  'ANTNSKATSI89617',
#  'Aaagiiisss',
#  'AerakisMartinos',
#  'AfroditeXig',
#  'AggelouNikos',
#  'AlexChalkiotis',
#  'Altzi',
#  'AndKapsambelis',
#  'AngelKalli1',
#  'Angio87',
#  'Anna70060868',
#  'AntennaNews',
#  'AntonioNewsWeb1',
#  'Aph_Kay',
#  'ArisSkamp',
#  'ArisZachos',
#  'AthensVoice',
#  'AvgiOnline',
#  'BAGGELHS5',
#  'BMarankoudake',
#  'Baba_171717',
#  'BeatKido',
#  'BillKouts1',
#  'Billakos_Billy',
#  'Bizznews',
#  'BlogNewsgr',
#  'BlossomAnthoula',
#  'BlumGeny',
#  'C12H22O12',
#  'CANEA67',
#  'CGEGR',
#  'CheapEripo',
#  'ChpThera',
#  'Chrysa00895',
#  'Circe90644603',
#  'CltrAltDelicius',
#  'CostasLapiotis',
#  'CucuvaYia',
#  'DHatzoudis',
#  'DKollyris',
# ...

# %%
df.groupby("source")['title'].count().reset_index().sort_values("title",ascending=False).head(20)
# Out:
#               source  title
# 228     PANGKAKISTOS    157
# 519             emsc     34
# 380       antenna.gr     29
# 945        pronewsgr     26
# 1042      thebest.gr     25
# 379      ant1news.gr     24
# 114   Ginakaragianni     22
# 367         anastool     20
# 497    earthquake_gr     19
# 533             eqgr     16
# 539       ertnews.gr     16
# 411   bankingnews.gr     16
# 731        lastquake     14
# 943       pronews.gr     14
# 401     athina984.gr     14
# 930       politic.gr     13
# 363          amna.gr     13
# 836      newsbomb.gr     12
# 883        panos_epi     12
# 821      neakriti.gr     12

# %%
df[df["source"]=="emsc"]
# Out:
#      type source                                          title  \
# 82      X   emsc  https://x.com/emsc/status/1927428143335329861
# 389     X   emsc  https://x.com/emsc/status/1927407596337549810
# 433     X   emsc  https://x.com/emsc/status/1927387391934742702
# 577     X   emsc  https://x.com/emsc/status/1927347092537610624
# 675     X   emsc  https://x.com/emsc/status/1927330779631141083
# 841     X   emsc  https://x.com/emsc/status/1927030783371313592
# 1700    X   emsc  https://x.com/emsc/status/1927182257673982274
# 1752    X   emsc  https://x.com/emsc/status/1927155107164037574
# 1785    X   emsc  https://x.com/emsc/status/1927155247656366270
# 2170    X   emsc  https://x.com/emsc/status/1927069265217167626
# 2181    X   emsc  https://x.com/emsc/status/1927043452040024089
# 2187    X   emsc  https://x.com/emsc/status/1927022497137823797
# 2200    X   emsc  https://x.com/emsc/status/1927006840010793202
# 2251    X   emsc  https://x.com/emsc/status/1926945789995053483
# ...

# %%
emsc_df = df[df["source"]=="emsc"]
emsc_df = emsc_df.reset_index(drop=True)
emsc_df
# Out:
#    type source                                          title  \
# 0     X   emsc  https://x.com/emsc/status/1927428143335329861
# 1     X   emsc  https://x.com/emsc/status/1927407596337549810
# 2     X   emsc  https://x.com/emsc/status/1927387391934742702
# 3     X   emsc  https://x.com/emsc/status/1927347092537610624
# 4     X   emsc  https://x.com/emsc/status/1927330779631141083
# 5     X   emsc  https://x.com/emsc/status/1927030783371313592
# 6     X   emsc  https://x.com/emsc/status/1927182257673982274
# 7     X   emsc  https://x.com/emsc/status/1927155107164037574
# 8     X   emsc  https://x.com/emsc/status/1927155247656366270
# 9     X   emsc  https://x.com/emsc/status/1927069265217167626
# 10    X   emsc  https://x.com/emsc/status/1927043452040024089
# 11    X   emsc  https://x.com/emsc/status/1927022497137823797
# 12    X   emsc  https://x.com/emsc/status/1927006840010793202
# 13    X   emsc  https://x.com/emsc/status/1926945789995053483
# ...

# %%
selected_sites = ['emsc', 'ertnews.gr', 'pronews.gr', 'thebest.gr', 'earthquake_gr']
filtered_df = df[df['source'].isin(selected_sites)]
filtered_df.reset_index(drop=True, inplace=True)
filtered_df = filtered_df.sort_values("source").reset_index(drop=True)
filtered_df
# Out:
#     type         source                                              title  \
# 0      X  earthquake_gr  https://x.com/earthquake_gr/status/19263907938...
# 1      X  earthquake_gr  https://x.com/earthquake_gr/status/19271558453...
# 2      X  earthquake_gr  https://x.com/earthquake_gr/status/19271568494...
# 3      X  earthquake_gr  https://x.com/earthquake_gr/status/19271024867...
# 4      X  earthquake_gr  https://x.com/earthquake_gr/status/19270058580...
# ..   ...            ...                                                ...
# 103  web     thebest.gr  Πάτρα: Συγκλονίζει ο 46χρονος Δημήτρης - «Έπιν...
# 104  web     thebest.gr  Τρίκαλα: Αβάσταχτος πόνος στην κηδεία του Στέφ...
# 105  web     thebest.gr  « Η Τέχνη της Διαφορετικότητας» στο Πανεπιστήμ...
# 106  web     thebest.gr  Πάτρα: Τροχαίο ατύχημα με τραυματισμό νεαρού δ...
# 107  web     thebest.gr                 Σεισμός 4,8 Ρίχτερ στον Κορινθιακό
#
# ...

# %%
filtered_df["source"].unique()
# Out:
# array(['earthquake_gr', 'emsc', 'ertnews.gr', 'pronews.gr', 'thebest.gr'],
#       dtype=object)

# %%
df2 = pd.read_csv("/content/drive/MyDrive/seismoi_csv!.csv", encoding='ISO-8859-7')
df2
# Out:
#      type             source  \
# 0     web      adieksodos.gr
# 1     web         antenna.gr
# 2     web         antenna.gr
# 3     web    nicemagazine.gr
# 4       X    fayssecretsssss
# ...   ...                ...
# 2785    X       PANGKAKISTOS
# 2786    X     ekklisiaonline
# 2787    X       g_prince_tak
# 2788  web   pentapostagma.gr
# 2789  web  halkidikivoice.gr
#
#                                                   title  \
# 0     Σεισμός 4,8 Ρίχτερ στον Κορινθιακό  Προβληματ...
# 1                                  Σεισμός στη Μεσσηνία
# 2     Κρήτη: Σφοδρή σύγκρουση τριών οχημάτων, ταυματ...
# 3     Σεισμός 4,8 Ρίχτερ στον Κορινθιακό  Προβληματ...
# 4     https://x.com/fayssecretsssss/status/192745726...
# ...                                                 ...
# 2785  https://x.com/PANGKAKISTOS/status/192638894749...
# 2786  https://x.com/ekklisiaonline/status/1926369528...
# 2787  https://x.com/g_prince_tak/status/192637505857...
# ...

# %%
all_df = pd.concat([df, df2], axis=0, ignore_index=True)
all_df
# Out:
#      type             source  \
# 0     web      adieksodos.gr
# 1     web         antenna.gr
# 2     web         antenna.gr
# 3     web    nicemagazine.gr
# 4       X    fayssecretsssss
# ...   ...                ...
# 5575    X       PANGKAKISTOS
# 5576    X     ekklisiaonline
# 5577    X       g_prince_tak
# 5578  web   pentapostagma.gr
# 5579  web  halkidikivoice.gr
#
#                                                   title  \
# 0     Σεισμός 4,8 Ρίχτερ στον Κορινθιακό  Προβληματ...
# 1                                  Σεισμός στη Μεσσηνία
# 2     Κρήτη: Σφοδρή σύγκρουση τριών οχημάτων, ταυματ...
# 3     Σεισμός 4,8 Ρίχτερ στον Κορινθιακό  Προβληματ...
# 4     https://x.com/fayssecretsssss/status/192745726...
# ...                                                 ...
# 5575  https://x.com/PANGKAKISTOS/status/192638894749...
# 5576  https://x.com/ekklisiaonline/status/1926369528...
# 5577  https://x.com/g_prince_tak/status/192637505857...
# ...
